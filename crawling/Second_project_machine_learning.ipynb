# %%
import pandas as pd
import numpy as np
df = pd.read_csv('beer_data.csv')
df
# Out:
#       id              name    image  bold  sparkling  sweet  tannic  acidic  \
# 0      0   7 - 복사본 (9).jpg   롬자엑스포트  0.80       0.00   0.08    0.04    0.04
# 1      1   7 - 복사본 (8).jpg  롱보드아일랜드  0.49       0.65   0.07    0.03    0.01
# 2      2   7 - 복사본 (7).jpg     르샤누아  0.26       0.73   0.08    0.01    0.01
# 3      3   7 - 복사본 (6).jpg    마레드수스  0.42       0.61   0.07    0.05    0.01
# 4      4   7 - 복사본 (5).jpg  몬티스섬머에일  0.16       0.00   0.33    0.05    0.00
# ..   ...               ...      ...   ...        ...    ...     ...     ...
# 117  117  1 - 복사본 (15).jpg      라쇼페  0.66       0.69   0.07    0.06    0.02
# 118  118  1 - 복사본 (14).jpg    레벤브로이  0.83       0.60   0.04    0.07    0.04
# 119  119  1 - 복사본 (13).jpg    레페브론드  0.36       0.64   0.08    0.04    0.05
# 120  120  1 - 복사본 (12).jpg     로얄더치  0.59       0.41   0.04    0.01    0.01
# 121  121               NaN      NaN   NaN        NaN    NaN     NaN     NaN
#
#      alcohol  category_id
# 0       4.73            0
# 1       7.55            0
# 2       7.99            0
# 3       8.00            0
# 4       9.39            0
# ..       ...          ...
# 117     4.31            0
# 118     6.00            0
# 119     9.04            0
# 120     4.03            0
# 121      NaN            0
#
# [122 rows x 10 columns]

# %%
df = df[['bold', 'sparkling', 'sweet', 'tannic', 'acidic', 'alcohol']]
df = df.iloc[:-1, :]
df
# Out:
#      bold  sparkling  sweet  tannic  acidic  alcohol
# 0    0.80       0.00   0.08    0.04    0.04     4.73
# 1    0.49       0.65   0.07    0.03    0.01     7.55
# 2    0.26       0.73   0.08    0.01    0.01     7.99
# 3    0.42       0.61   0.07    0.05    0.01     8.00
# 4    0.16       0.00   0.33    0.05    0.00     9.39
# ..    ...        ...    ...     ...     ...      ...
# 116  0.31       0.73   0.07    0.07    0.03     7.79
# 117  0.66       0.69   0.07    0.06    0.02     4.31
# 118  0.83       0.60   0.04    0.07    0.04     6.00
# 119  0.36       0.64   0.08    0.04    0.05     9.04
# 120  0.59       0.41   0.04    0.01    0.01     4.03
#
# [121 rows x 6 columns]

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5).fit(df)

df['cluster_id'] = kmeans.labels_
df
# Out:
#      bold  sparkling  sweet  tannic  acidic  alcohol  cluster_id
# 0    0.80       0.00   0.08    0.04    0.04     4.73           0
# 1    0.49       0.65   0.07    0.03    0.01     7.55           3
# 2    0.26       0.73   0.08    0.01    0.01     7.99           3
# 3    0.42       0.61   0.07    0.05    0.01     8.00           3
# 4    0.16       0.00   0.33    0.05    0.00     9.39           1
# ..    ...        ...    ...     ...     ...      ...         ...
# 116  0.31       0.73   0.07    0.07    0.03     7.79           3
# 117  0.66       0.69   0.07    0.06    0.02     4.31           0
# 118  0.83       0.60   0.04    0.07    0.04     6.00           4
# 119  0.36       0.64   0.08    0.04    0.05     9.04           1
# 120  0.59       0.41   0.04    0.01    0.01     4.03           0
#
# [121 rows x 7 columns]

# %%
import os
import random
import pandas as pd
import numpy as np
# 'D:\\ringa\\web\\second_project\\crawling'에서 작업 중
path_dir = './data/'
file_list  = []
for item in os.listdir(path_dir):
    if '.txt' in item:
        file_list.append(item)

# cluster id 불러오기
df = pd.read_csv('cluster.csv')
cluster = list(df.cluster_id)

# 이미지 String 변환
image_path_dir = './images/'
image_str_list  = []
for item in os.listdir(image_path_dir):
    image_str_list.append(item)
        
# 맥주 이름
titles = []
for item in file_list:
    start = 0
    end = 0
    for i in range(len(item)):
        if item[i] == '_':
            start = i + 1
    for i in range(start, len(item)):
        if item[i] == '.':
            end = i
    titles.append(item[start:end])


# 바디감(light bold) bd
# 탄산감(sparkling) sp
# 달콤함(dry sweet) sw
# 씁쓸함(smooth tannic) bit
# 신맛(soft acidic) acid

beer_state_sort = {}
# beer state sort 딕셔너리
# beer state sort = {'맥주이름' : [맛 구분]}
# 맛 구분 = [['바디감'  ???] , ['탄산감' : ???], ['달콤함' : ???], ['씁쓸함' : ???], ['신맛' : ???]]



for item in file_list:
    try:
        f = open('./data/' + item, 'r', encoding='euc-kr')
        bd, sp, sw, bit, acid = round(random.uniform(0, 1), 2), [], 0, 0, 0
        content = f.readlines()
        
        # 맥주 이름
        start = 0
        end = 0
        for i in range(len(item)):
            if item[i] == '_':
                start = i + 1
        for i in range(start, len(item)):
            if item[i] == '.':
                end = i
        title = (item[start:end])

        # 이미지 파일 이름
        image_name = image_str_list.pop()

        # 각 맛 구분 찾아내기
        # 탄산감(sparkling) sp
        start = 0
        end = 0
        for j in range(len(content[53])):
            if content[53][j] == '!':
                start = j + 4
                break
        for j in range(start, len(content[53])):
            if content[53][j] == '번':
                end = j
                break
        sp.append((content[53][start:end]))

    
        start = 0
        end = 0
        for j in range(len(content[54])):
            if content[54][j] == '!':
                start = j + 4
                break
        for j in range(start, len(content[54])):
            if content[54][j] == '번':
                end = j
                break
        sp.append((content[54][start:end]))

        sp = list(map(float, sp))
        if sp[0] == sp[1] == 0:
            sp = 0
        else:
            sp = round(sp[0] / (sp[0] + sp[1]), 2)

        # 달콤함(dry sweet) sw
        start = 0
        end = 0
        for j in range(len(content[20])):
            if content[20][j] == ':':
                start = j+2
                break
        for j in range(start, len(content[20])):
            if content[20][j] == '%':
                end = j
                break
        sw = round(0.01 * float(content[20][start:end]), 2)

        # 씁쓸함(smooth tannic) bit
        start = 0
        end = 0
        for j in range(len(content[21])):
            if content[21][j] == ':':
                start = j+2
                break
        for j in range(start, len(content[21])):
            if content[21][j] == '%':
                end = j
                break
        bit = round(0.01 * float(content[21][start:end]), 2)

        # 신맛(soft acidic) acid
        start = 0
        end = 0
        for j in range(len(content[30])):
            if content[30][j] == ':':
                start = j+2
                break
        for j in range(start, len(content[30])):
            if content[30][j] == '%':
                end = j
                break
        acid = round(0.01 * float(content[30][start:end]),2)

        # 알코올 도수
        alcohol = round(random.uniform(4, 10), 2)

        beer_state_sort[title] = [image_name, title ,bd, sp, sw, bit, acid, alcohol]

        f.close()
    except: 
        print("Error    " + item)
        pass

for title in titles:
    if title in beer_state_sort.keys(): 
        print(beer_state_sort[title])

    numbering = [i for i in range(150)]
    count = 0
    for i in beer_state_sort.values(): # numbering[count]
        str = "insert into app_product values ({}, '{}', '{}', {}, {}, {});".format(
            numbering[count], i[1], i[0], i[7], cluster[count], 1)
        count += 1
        print(str)
# Out:
# ['7 - 복사본 (9).jpg', '롬자엑스포트', 0.44, 0.0, 0.08, 0.04, 0.04, 6.67]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);
# ['7 - 복사본 (8).jpg', '롱보드아일랜드', 0.84, 0.65, 0.07, 0.03, 0.01, 4.32]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);
# ['7 - 복사본 (7).jpg', '르샤누아', 0.03, 0.73, 0.08, 0.01, 0.01, 7.38]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);
# ['7 - 복사본 (6).jpg', '마레드수스', 0.08, 0.61, 0.07, 0.05, 0.01, 5.21]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);
# ['7 - 복사본 (5).jpg', '몬티스섬머에일', 0.82, 0, 0.33, 0.05, 0.0, 9.5]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# ...
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);
# ['1 - 복사본 (12).jpg', '로얄더치', 0.62, 0.41, 0.04, 0.01, 0.01, 5.05]
# insert into app_product values (0, '롬자엑스포트', '7 - 복사본 (9).jpg', 6.67, 0, 1);
# insert into app_product values (1, '롱보드아일랜드', '7 - 복사본 (8).jpg', 4.32, 3, 1);
# insert into app_product values (2, '르샤누아', '7 - 복사본 (7).jpg', 7.38, 3, 1);
# insert into app_product values (3, '마레드수스', '7 - 복사본 (6).jpg', 5.21, 3, 1);
# insert into app_product values (4, '몬티스섬머에일', '7 - 복사본 (5).jpg', 9.5, 3, 1);
# insert into app_product values (5, '몬티스오리지널에일', '7 - 복사본 (4).jpg', 8.15, 3, 1);
# insert into app_product values (6, '민타임', '7 - 복사본 (3).jpg', 4.98, 3, 1);
# insert into app_product values (7, '스윙켈스맥주', '7 - 복사본 (2).jpg', 8.83, 4, 1);
# insert into app_product values (8, '바이엔슈테판', '7 - 복사본 (16).jpg', 5.6, 1, 1);
# insert into app_product values (9, '바이엔슈테판크리스탈', '7 - 복사본 (15).jpg', 4.55, 3, 1);
# insert into app_product values (10, '바이엔슈테판헤페바이스', '7 - 복사본 (14).jpg', 8.79, 1, 1);
# insert into app_product values (11, '바이엔슈테판비투스', '7 - 복사본 (13).jpg', 8.95, 3, 1);
# insert into app_product values (12, '발렌틴스', '7 - 복사본 (12).jpg', 5.2, 4, 1);
# insert into app_product values (13, '마이쉘 맥주', '7 - 복사본 (11).jpg', 4.48, 3, 1);
# insert into app_product values (14, '베어비어휘트바이젠', '7 - 복사본 (10).jpg', 6.06, 0, 1);
# insert into app_product values (15, '밸라스트포인트IPA', '6.jpg', 9.44, 3, 1);
# insert into app_product values (16, '밸라스트포인트스컬핀', '6 - 복사본.jpg', 6.81, 0, 1);
# insert into app_product values (17, '밸라스트포인트칼리코', '6 - 복사본 (9).jpg', 5.66, 4, 1);
# insert into app_product values (18, '발티카no3', '6 - 복사본 (8).jpg', 8.9, 0, 1);
# insert into app_product values (19, '발티카no7', '6 - 복사본 (7).jpg', 4.31, 1, 1);
# insert into app_product values (20, '버드아이스', '6 - 복사본 (6).jpg', 4.51, 2, 1);
# insert into app_product values (21, '버드와이저', '6 - 복사본 (5).jpg', 5.54, 0, 1);
# insert into app_product values (22, '벡스', '6 - 복사본 (4).jpg', 4.38, 2, 1);
# insert into app_product values (23, '벡스다크', '6 - 복사본 (3).jpg', 6.13, 0, 1);
# insert into app_product values (24, '몬티스 맥주', '6 - 복사본 (2).jpg', 9.73, 3, 1);
# insert into app_product values (25, '벨킨스', '6 - 복사본 (17).jpg', 5.45, 0, 1);
# insert into app_product values (26, '부드바르', '6 - 복사본 (16).jpg', 7.25, 4, 1);
# insert into app_product values (27, '붐버스', '6 - 복사본 (15).jpg', 5.13, 3, 1);
# insert into app_product values (28, '브로우체코', '6 - 복사본 (15) copy.jpg', 4.93, 3, 1);
# insert into app_product values (29, '브루클린IPA', '6 - 복사본 (15) copy 2.jpg', 8.39, 3, 1);
# insert into app_product values (30, '브루클린라거', '6 - 복사본 (14).jpg', 4.34, 0, 1);
# insert into app_product values (31, '브루클린브라운에일', '6 - 복사본 (13).jpg', 5.6, 0, 1);
# insert into app_product values (32, '비라모레띠', '6 - 복사본 (12).jpg', 8.42, 0, 1);
# insert into app_product values (33, '칼스버그 맥주', '6 - 복사본 (11).jpg', 4.78, 0, 1);
# insert into app_product values (34, '사이공 맥주', '6 - 복사본 (10).jpg', 7.13, 1, 1);
# insert into app_product values (35, '산미구엘라이트', '5.jpg', 5.58, 3, 1);
# insert into app_product values (36, '산미구엘세르베자', '5 - 복사본.jpg', 7.27, 0, 1);
# insert into app_product values (37, '삿포로프리미엄', '5 - 복사본 (9).jpg', 7.96, 4, 1);
# insert into app_product values (38, '세인트버나두스 트리펠', '5 - 복사본 (8).jpg', 8.02, 2, 1);
# insert into app_product values (39, '슈나이더운저오리지날', '5 - 복사본 (7).jpg', 6.57, 0, 1);
# insert into app_product values (40, '슈나이더아벤티누스', '5 - 복사본 (6).jpg', 7.84, 1, 1);
# insert into app_product values (41, '슈나이더마인호펜바이세', '5 - 복사본 (5).jpg', 4.42, 0, 1);
# insert into app_product values (42, '에스트렐라 맥주', '5 - 복사본 (4).jpg', 9.36, 1, 1);
# insert into app_product values (43, '바바리아 프리미엄', '5 - 복사본 (3).jpg', 4.43, 1, 1);
# insert into app_product values (44, '모젤 맥주', '5 - 복사본 (2).jpg', 7.47, 2, 1);
# insert into app_product values (45, '스파텐 맥주', '5 - 복사본 (17).jpg', 6.09, 4, 1);
# insert into app_product values (46, '칭따오 맥주', '5 - 복사본 (16).jpg', 9.05, 4, 1);
# insert into app_product values (47, '그롤쉬 프리미엄 라거', '5 - 복사본 (15).jpg', 4.73, 1, 1);
# insert into app_product values (48, '슈퍼복 맥주', '5 - 복사본 (14).jpg', 9.94, 3, 1);
# insert into app_product values (49, '감브리너스 맥주', '5 - 복사본 (13).jpg', 8.41, 0, 1);
# insert into app_product values (50, '발리골드 맥주', '5 - 복사본 (12).jpg', 6.66, 1, 1);
# insert into app_product values (51, '벨틴스 맥주', '5 - 복사본 (11).jpg', 6.05, 2, 1);
# insert into app_product values (52, 'DAB 맥주', '5 - 복사본 (10).jpg', 7.08, 2, 1);
# insert into app_product values (53, '볼비어라거맥주', '4.jpg', 8.81, 1, 1);
# insert into app_product values (54, '레페브라운 에일', '4 - 복사본.jpg', 5.32, 2, 1);
# insert into app_product values (55, '호가든 오리지날', '4 - 복사본 (9).jpg', 5.81, 2, 1);
# insert into app_product values (56, '스텔라 아르투아 맥주', '4 - 복사본 (8).jpg', 7.54, 2, 1);
# insert into app_product values (57, '기린이치방 맥주', '4 - 복사본 (7).jpg', 6.37, 4, 1);
# insert into app_product values (58, '벡스 맥주', '4 - 복사본 (6).jpg', 7.94, 4, 1);
# insert into app_product values (59, '아사히 드라이 블랙 맥주', '4 - 복사본 (5).jpg', 6.78, 2, 1);
# insert into app_product values (60, '코젤 다크', '4 - 복사본 (4).jpg', 5.0, 3, 1);
# insert into app_product values (61, '펠트슐로센 다크', '4 - 복사본 (3).jpg', 4.64, 0, 1);
# insert into app_product values (62, '펠트슐로센 헤페바이젠', '4 - 복사본 (2).jpg', 8.43, 4, 1);
# insert into app_product values (63, '와바 둔켈 맥주', '4 - 복사본 (17).jpg', 8.63, 1, 1);
# insert into app_product values (64, '에델바이스 스노우 후레쉬', '4 - 복사본 (16).jpg', 9.22, 1, 1);
# insert into app_product values (65, '에딩거 바이스비어', '4 - 복사본 (15).jpg', 8.48, 2, 1);
# insert into app_product values (66, '파울라너 맥주', '4 - 복사본 (14).jpg', 4.74, 3, 1);
# insert into app_product values (67, '쇼퍼호퍼 맥주', '4 - 복사본 (13).jpg', 4.42, 2, 1);
# insert into app_product values (68, '볼비어헤페바이젠', '4 - 복사본 (12).jpg', 4.0, 1, 1);
# insert into app_product values (69, '기네스 드래프트', '4 - 복사본 (11).jpg', 4.26, 3, 1);
# insert into app_product values (70, '기네스 오리지날', '4 - 복사본 (10).jpg', 4.76, 1, 1);
# insert into app_product values (71, '호가든 맥주', '3.png', 4.78, 1, 1);
# insert into app_product values (72, '호가든 그랑크루', '3 - 복사본.png', 9.36, 1, 1);
# insert into app_product values (73, '호가든 포비든프룻', '3 - 복사본 (9).png', 9.47, 2, 1);
# insert into app_product values (74, '하이트제로 무알콜', '3 - 복사본 (8).png', 7.02, 4, 1);
# insert into app_product values (75, '밀러 무알콜 맥주', '3 - 복사본 (7).png', 9.62, 1, 1);
# insert into app_product values (76, 'DORADA 맥주', '3 - 복사본 (6).png', 9.77, 3, 1);
# insert into app_product values (77, '대만허니비어', '3 - 복사본 (5).png', 4.63, 3, 1);
# insert into app_product values (78, '대만 파인애플맥주', '3 - 복사본 (4).png', 4.15, 3, 1);
# insert into app_product values (79, '대만망고맥주', '3 - 복사본 (3).png', 8.07, 2, 1);
# insert into app_product values (80, '지카시보리', '3 - 복사본 (2).png', 7.77, 2, 1);
# insert into app_product values (81, '머드쉐이크 초코', '3 - 복사본 (17).png', 6.42, 1, 1);
# insert into app_product values (82, '머드쉐이크 카푸치노', '3 - 복사본 (16).png', 7.64, 3, 1);
# insert into app_product values (83, '바카디모히또', '3 - 복사본 (15).png', 5.95, 3, 1);
# insert into app_product values (84, '웨팅어프라이', '3 - 복사본 (14).png', 8.8, 1, 1);
# insert into app_product values (85, '버니니 맥주', '3 - 복사본 (13).png', 8.92, 2, 1);
# insert into app_product values (86, '버니니 블러쉬', '3 - 복사본 (12).png', 5.95, 3, 1);
# insert into app_product values (87, '클라우스탈러', '3 - 복사본 (11).png', 4.07, 2, 1);
# insert into app_product values (88, '바바리아 무알콜레귤러', '3 - 복사본 (10).png', 8.48, 0, 1);
# insert into app_product values (89, '바바리아 무알콜레몬', '2.jpg', 8.69, 3, 1);
# insert into app_product values (90, '바바리아 무알콜애플', '2 - 복사본.jpg', 4.95, 1, 1);
# insert into app_product values (91, '비트버거 맥주', '2 - 복사본 (9).jpg', 9.21, 1, 1);
# insert into app_product values (92, '크롬바커 맥주', '2 - 복사본 (8).jpg', 4.85, 3, 1);
# insert into app_product values (93, 'kgb레몬', '2 - 복사본 (5).jpg', 6.1, 1, 1);
# insert into app_product values (94, 'kgb크랜베리', '2 - 복사본 (4).jpg', 5.09, 3, 1);
# insert into app_product values (95, 'kgb그레이프', '2 - 복사본 (3).jpg', 5.54, 1, 1);
# insert into app_product values (96, '크루저 블루베리', '2 - 복사본 (2).jpg', 4.47, 3, 1);
# insert into app_product values (97, '크루저라즈베리', '2 - 복사본 (17).jpg', 6.25, 3, 1);
# insert into app_product values (98, '후치아이스애플', '2 - 복사본 (16).jpg', 9.42, 1, 1);
# insert into app_product values (99, '후치아이스오렌지', '2 - 복사본 (15).jpg', 9.65, 4, 1);
# insert into app_product values (100, '코파버그', '2 - 복사본 (14).jpg', 8.79, 3, 1);
# insert into app_product values (101, '써머스비 사이더', '2 - 복사본 (13).jpg', 7.49, 3, 1);
# insert into app_product values (102, '마가리타 맥주', '2 - 복사본 (12).jpg', 5.51, 3, 1);
# insert into app_product values (103, 'Savanna Dry', '2 - 복사본 (11).jpg', 4.64, 2, 1);
# insert into app_product values (104, '가펠쾰쉬', '2 - 복사본 (10).jpg', 9.47, 1, 1);
# insert into app_product values (105, '그레이트 화이트 맥주', '11111.jpg', 4.83, 1, 1);
# insert into app_product values (106, '그림버겐 더블', '1.jpg', 5.73, 4, 1);
# insert into app_product values (107, '그림버겐클래식', '1 - 복사본.jpg', 8.95, 3, 1);
# insert into app_product values (108, '그롤쉬 스윙탑', '1 - 복사본 (9).jpg', 8.44, 1, 1);
# insert into app_product values (109, '네그라모델로', '1 - 복사본 (8).jpg', 7.85, 3, 1);
# insert into app_product values (110, 'Newcastle Brown Ale', '1 - 복사본 (7).jpg', 9.74, 3, 1);
# insert into app_product values (111, '다스블론드', '1 - 복사본 (6).jpg', 4.01, 1, 1);
# insert into app_product values (112, 'Dead Guy ale', '1 - 복사본 (5).jpg', 6.35, 3, 1);
# insert into app_product values (113, 'TECATE 맥주', '1 - 복사본 (4).jpg', 4.73, 3, 1);
# insert into app_product values (114, '데카테', '1 - 복사본 (3).jpg', 9.07, 3, 1);
# insert into app_product values (115, '듀라커둔켈', '1 - 복사본 (17).jpg', 9.65, 3, 1);
# insert into app_product values (116, '듀벨', '1 - 복사본 (16).jpg', 5.17, 3, 1);
# insert into app_product values (117, '라쇼페', '1 - 복사본 (15).jpg', 4.12, 1, 1);
# insert into app_product values (118, '레벤브로이', '1 - 복사본 (14).jpg', 6.55, 1, 1);
# insert into app_product values (119, '레페브론드', '1 - 복사본 (13).jpg', 6.37, 3, 1);
# insert into app_product values (120, '로얄더치', '1 - 복사본 (12).jpg', 5.05, 1, 1);

# %%
# beer state sort 딕셔너리
# beer state sort = {'맥주이름' : [맛 구분]}
# 맛 구분 = [['바디감'  ???] , ['탄산감' : ???], ['달콤함' : ???], ['씁쓸함' : ???], ['신맛' : ???]]
bd, spa, sw, tan, acid = [], [], [], [], []
for title in titles:
    if title in beer_state_sort.keys():  
        bd.append(beer_state_sort[title][2])
        spa.append(beer_state_sort[title][3])
        sw.append(beer_state_sort[title][4])
        tan.append(beer_state_sort[title][5])
        acid.append(beer_state_sort[title][6])
